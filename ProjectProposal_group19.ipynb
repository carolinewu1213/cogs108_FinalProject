# %% [markdown]
# # COGS 108 - Final Project Proposal

# %% [markdown]
# # Names
#
# - Xuan Jiang
# - Jiafeng Wu
# - Yian He
# - Muen Hsu
# - Zixuan Zhai
# - Jiaxi Lin

# %% [markdown]
# # Research Question

# %% [markdown]
# Are diabetic individuals with higher BMI (Body Mass Index) more likely to have higher health insurance claim amounts in the United States?

# %% [markdown]
# # Background and Prior Work

# %% [markdown]
# In this project, we aim to investigate the correlation between the Body Mass Index (BMI) of diabetic individuals and their health insurance claim amounts. Insurance claim analysis helps insurance companies to detect fraud claims and predict future claims and risks. Moreover, by monitoring the historical claim data, insurance companies can create new insurance products to conform to new trends that are detected from the claim data to maximize company profits. In healthcare, there are various health factors and demographic factors that affect the claim amounts of an individual's health insurance, therefore, various customized health insurance plans are created by insurance companies to satisfy customers’ demands and optimize companies’ profits.
# The claim amount represents the sum of money that the insurance company pays to the beneficiary when the insurance reaches its maturity. Health insurance is a type of insurance that provides coverage for a portion of an individual's medical expenses. The extent of coverage provided by health insurance is determined by the specific conditions in the policy, governing the amount of expenses that will be reimbursed by the insurance company. When assessing an individual's eligibility for health-related insurance, insurance companies take various factors into consideration. One of these factors is Body Mass Index (BMI), which helps determine the person's risk of developing health issues.
#
# Body mass index (BMI) is a measure of body fat based on height and weight. In accordance with the weight status categories defined by BMI, individuals with a BMI falling between 25 and 29.9 are categorized as overweight, while those with a BMI exceeding 30 are classified as obese. Increased rates of higher BMI have emerged as a major contributing factor to the growing incidence of diabetes<a name="cite_ref-1"></a>[<sup>[1]</sup>](#cite_note-1). Diabetes is a costly chronic disease  occurs when the pancreas fails to produce sufficient insulin or when the body is unable to effectively utilize the insulin it generates<a name="cite_ref-2"></a>[<sup>[2]</sup>](#cite_note-2). In a study conducted by Khan et al., it was found that individuals who have been diagnosed with diabetes tend to spend $8941 more on medical expenses compared to those who do not have a diabetes diagnosis. Furthermore, the study observed that the compounded annual growth rate in per capita annual medical expenditures was approximately 9\% higher among individuals with diabetes<a name="cite_ref-3"></a>[<sup>[3]</sup>](#cite_note-3). Evidence from Finkelstein et al. suggested obesity-related medical expenditures takes up 9.1 percent of total annual cost<a name="cite_ref-4"></a>[<sup>[4]</sup>](#cite_note-4). Due to the elevated health risks associated with higher BMI values, individuals with diabetes who also have higher BMI tend to have higher medical expenditures compared with others.
#
# Previous studies focused on analyzing the relationship between diabetic status and medical expenditures, hoping to highlight the positive correlation between diabetes and the economic burden placed on them. In our study, we try to step further to investigate the possible correlation of the BMI of diabetics individuals with regard to the health insurance claim amounts.
#
# <a name="cite_note-1"></a>1. [^](#cite_ref-1) Rendell, M. S. (2023, Jan 29). Obesity and diabetes: The final frontier. *Expert Review of Endocrinology &amp; Metabolism, 18*(1), 81–94. https://doi.org/10.1080/17446651.2023.2168643
# <br>
# <a name="cite_note-2"></a>2. [^](#cite_ref-2)  World Health Organization. (2023, April 5). *Diabetes*. World Health Organization. https://www.who.int/news-room/fact-sheets/detail/diabetes#:~:text=Diabetes%20is%20a%20chronic%20disease,hormone%20that%20 regulates%20blood%20 glucose.
# <br>
# <a name="cite_note-3"></a>3. [^](#cite_ref-3) Khan, T., Yang, J., & Wozniak, G. (2021, February 2). *Trends in medical expenditures prior to diabetes diagnosis: The early burden of diabetes*. Population health management. https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7875131/
# <br>
# <a name="cite_note-4"></a>4. [^](#cite_ref-4) Eric A. Finkelstein, Ian C. Fiebelkorn, Guijing Wang (2003). National Medical Spending Attribute to Overweight and Obesity: How Much, and Who’s Paying? *Health Affairs, 22*(1). https://doi.org/10.1377/hlthaff.W3.219

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Our null hypothesis states that there is no correlation between the Body Mass Index of diabetic individuals and the health insurance claim amounts in the United States.
#
# Our alternative hypothesis states that diabetic individuals with higher Body Mass Index tend to have higher health insurance claim amounts regardless of other demographic factors in the United States.

# %% [markdown]
# # Data

# %% [markdown]
# The dataset should encompass at least 1000 individuals under observation. Each individual's information should be captured and recorded using the following variables: Patient number, age, gender, BMI, diabetic status, other health statuses, and the annual health insurance claim.
# The collected data will be stored in a tabular format, with certain entries possibly missing. To ensure data integrity, our research group will employ a process of data organization by removing patients with missing values from the dataset.
# <br>
# <br>
# Datasets:
# <br>
# $\;\;\;\;\;\;$ **(1) insurance_data.csv**
# <br>
# [Insurance Claim Analysis: Demographic and Health | Kaggle](https://www.kaggle.com/datasets/thedevastator/insurance-claim-analysis-demographic-and-health?resource=download)
# <br>
# <br>
# $\;\;\;\;\;\;$ **(2) US Health Insurance Dataset.csv**
# <br>
# [US Health Insurance Dataset | Kaggle](https://www.kaggle.com/datasets/teertha/ushealthinsurancedataset)
# <br>
# <br>
# Both datasets pertain to health insurance claim amounts and health factors concerning the American population. By merging these datasets, the overall data volume is increased, thereby enhancing the precision of correlation analysis and similar analytical procedures. The combined dataset encompasses the following variables: index, PatientID, age, gender, BMI, blood pressure, diabetic status, number of children, smoking status, region, and claim amount. Our current analysis aims to assess the relevance of all these variables in relation to our primary research objective, which focuses on determining the impact of various factors on insurance claims. Consequently, we are conducting a meticulous evaluation of the inclusion of certain variables, such as smoker status and region, as they may not directly contribute to our focused investigation.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# We chose to explore the relationship between diabetics with higher BMI (body mass index) and Medicare reimbursement amounts. The information we used in our study came from open access sources, which means that there are no ethical issues with the data itself. However, as it relates to human health, we need to consider the privacy issues involved. All data and contextual information used in our study were obtained from the authoritative website and journal Kaggle.com, a public database designed for the disciplines of data science and machine learning. Kaggle.com also makes sure we are accessed with appropriate usage filters. As an open access platform, Kaggle.com ensures that the datasets available for use are appropriately anonymized and comply with relevant privacy regulations. Therefore, the data we use complies with ethical guidelines and privacy regulations.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# * **Effective Communication** : We value the importance of clear and effective communication. Group meetings are well-organized each time with questions and materials needed prepared. Each member will be heard and thoroughly discuss their concerns. Various ways of meeting are accepted (in person & through Zoom).
# * **Active Collaboration** : We value each other’s contributions and time. Collaboration and cooperation are the keys to help our group succeed in the project and also help each other to grow in academics and personal life.
# * **Roles and Responsibilities** : We assign each member their own roles and responsibilities. All parts of the project can be done individually or with collaboration. All members are held accountable for the project and should have fair distribution of group works with a clear understanding of the group’s work. Each member should actively participate in the group discussion to be clear of the group’s work float and decision-making process. Each member should contribute to the group’s success.
# * **Timelines and Deadlines** : We set clear timelines and deadlines for our project. Each task should be completed within an indicated period of time. This helps with providing a positive working environment for everyone and keeps the project on float. Timelines and deadlines are flexible with acknowledgments in the group to give each member enough time to complete their tasks.
# * **Conflict Resolution** : We acknowledge that conflicts or disagreements may arise during the project as members might have differences. Respectful communications and conversations are required to resolve conflicts in the group. Conflicts can be resolved through discussions.
# * **Regular Meetings and Progress Updates** : We will post progress updates in the group’s discussion board to let everyone check on their progress and make sure no one is left behind. Future plans and meetings can be well-adjusted accordingly.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# Specify your team's project timeline. An example timeline has been provided. Changes the dates, times, names, and details to fit your group's plan.
#
# If you think you will need any special resources or training outside what we have covered in COGS 108 to solve your problem, then your proposal should state these clearly. For example, if you have selected a problem that involves implementing multiple neural networks, please state this so we can make sure you are on track for success and so we can point you to resources you will need to implement your project. Note that you are not required to use outside methods.
#
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 7/8  |  9 AM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 7/11 | 12 AM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 7/13 | 12 AM  | Edit, finalize, and submit proposal; Search for datasets  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part(Xuan Jiang)   |
# | 7/16  | 9 AM  | Import & Wrangle Data (Yian He, Jiaxi Lin); EDA (Xuan Jiang, Muen Hsu, Yian He) | Review/Edit wrangling/EDA(Zixuan Zhai, Jiafeng Wu, Jiaxi Lin); Discuss Analysis Plan  (all)  |
# | 7/20  | 12 AM  | Finalize wrangling/EDA(Yian He, Jiaxi Lin); Begin Analysis (Xuan Jiang, Muen Hsu) | Discuss/edit Analysis; Complete project check-in |
# | 8/3  | 9 AM  | Complete analysis; Draft results/conclusion/discussion (Zixuan Zhai, Jiafeng Wu)| Discuss/edit full project |
# | 8/4  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
